# %% [markdown]
# # Load Data

# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('job_train.csv')
test_df = pd.read_csv('job_test.csv')
attr_d = pd.read_csv('속성_D_코드.csv')
attr_h = pd.read_csv('속성_H_코드.csv')
attr_l = pd.read_csv('속성_L_코드.csv')

# %%
job_df = pd.concat([train_df,test_df],axis=0)

# %% [markdown]
# # Pre-Processing

# %%
# 콘텐츠 속성코드 레프트 조인
job_df2 = pd.merge(job_df, attr_d, how='left', left_on='contents_attribute_d', right_on='속성 D 코드')
job_df2 = pd.merge(job_df2, attr_h, how='left', left_on='contents_attribute_h', right_on='속성 H 코드')
job_df2 = pd.merge(job_df2, attr_l, how='left', left_on='contents_attribute_l', right_on='속성 L 코드')

# 콘텐츠 속성으로 컬럼명 변경
job_df2 = job_df2.rename(columns={'속성 D 코드':'contents_attr_d_c',
                                  '속성 D 대분류코드':'contents_attr_d_l',
                                  '속성 D 중분류코드':'contents_attr_d_m',
                                  '속성 D 소분류코드':'contents_attr_d_s',
                                  '속성 D 세분류코드':'contents_attr_d_ss',
                                  '속성 L 코드':'contents_attr_l_c',
                                  '속성 L 대분류코드':'contents_attr_l_l',
                                  '속성 L 중분류코드':'contents_attr_l_m',
                                  '속성 L 소분류코드':'contents_attr_l_s',
                                  '속성 L 세분류코드':'contents_attr_l_ss',
                                  '속성 H 코드':'contents_attr_h_c',
                                  '속성 H 대분류코드':'contents_attr_h_l',
                                  '속성 H 중분류코드':'contents_attr_h_m'})

# %%
# 유저 선호1 속성코드 레프트 조인
job_df2 = pd.merge(job_df2, attr_d, how='left', left_on='person_prefer_d_1', right_on='속성 D 코드')
job_df2 = pd.merge(job_df2, attr_h, how='left', left_on='person_prefer_h_1', right_on='속성 H 코드')

# 유저 선호1 속성으로 컬럼명 변경
job_df2 = job_df2.rename(columns={'속성 D 코드':'person_prefer_d1_c',
                                  '속성 D 대분류코드':'person_prefer_d1_l',
                                  '속성 D 중분류코드':'person_prefer_d1_m',
                                  '속성 D 소분류코드':'person_prefer_d1_s',
                                  '속성 D 세분류코드':'person_prefer_d1_ss',
                                  '속성 H 코드':'person_prefer_h1_c',
                                  '속성 H 대분류코드':'person_prefer_h1_l',
                                  '속성 H 중분류코드':'person_prefer_h1_m'})

# %%
# 유저 선호2 속성코드 레프트 조인
job_df2 = pd.merge(job_df2, attr_d, how='left', left_on='person_prefer_d_2', right_on='속성 D 코드')
job_df2 = pd.merge(job_df2, attr_h, how='left', left_on='person_prefer_h_2', right_on='속성 H 코드')

# 유저 선호2 속성으로 컬럼명 변경
job_df2 = job_df2.rename(columns={'속성 D 코드':'person_prefer_d2_c',
                                  '속성 D 대분류코드':'person_prefer_d2_l',
                                  '속성 D 중분류코드':'person_prefer_d2_m',
                                  '속성 D 소분류코드':'person_prefer_d2_s',
                                  '속성 D 세분류코드':'person_prefer_d2_ss',
                                  '속성 H 코드':'person_prefer_h2_c',
                                  '속성 H 대분류코드':'person_prefer_h2_l',
                                  '속성 H 중분류코드':'person_prefer_h2_m'})

# %%
# 유저 선호3 속성코드 레프트 조인
job_df2 = pd.merge(job_df2, attr_d, how='left', left_on='person_prefer_d_3', right_on='속성 D 코드')
job_df2 = pd.merge(job_df2, attr_h, how='left', left_on='person_prefer_h_3', right_on='속성 H 코드')

# 유저 선호3 속성으로 컬럼명 변경
job_df2 = job_df2.rename(columns={'속성 D 코드':'person_prefer_d3_c',
                                  '속성 D 대분류코드':'person_prefer_d3_l',
                                  '속성 D 중분류코드':'person_prefer_d3_m',
                                  '속성 D 소분류코드':'person_prefer_d3_s',
                                  '속성 D 세분류코드':'person_prefer_d3_ss',
                                  '속성 H 코드':'person_prefer_h3_c',
                                  '속성 H 대분류코드':'person_prefer_h3_l',
                                  '속성 H 중분류코드':'person_prefer_h3_m'})

# %%
# 매치여부 컬럼명 변경
# c : 속성코드 / l : 대분류 / m : 중분류 / s : 소분류 / ss : 세부분류
job_df2 = job_df2.rename(columns={'d_s_match_yn':'d1_c_match_yn',
                                  'd_m_match_yn':'d1_ss_match_yn',
                                  'h_s_match_yn':'h1_c_match_yn',
                                  'd_l_match_yn':'d1_l_match_yn',
                                  'h_l_match_yn':'h1_l_match_yn',
                                  'h_m_match_yn':'h1_m_match_yn'})

# %%
# 매칭여부 컬럼 생성
# d1
job_df2['d1_m_match_yn'] = np.where(job_df2.person_prefer_d1_m == job_df2.contents_attr_d_m, True, False)
job_df2['d1_s_match_yn'] = np.where(job_df2.person_prefer_d1_s == job_df2.contents_attr_d_s, True, False)

#d2
job_df2['d2_c_match_yn'] = np.where(job_df2.person_prefer_d2_c == job_df2.contents_attr_d_c, True, False)
job_df2['d2_l_match_yn'] = np.where(job_df2.person_prefer_d2_l == job_df2.contents_attr_d_l, True, False)
job_df2['d2_m_match_yn'] = np.where(job_df2.person_prefer_d2_m == job_df2.contents_attr_d_m, True, False)
job_df2['d2_s_match_yn'] = np.where(job_df2.person_prefer_d2_s == job_df2.contents_attr_d_s, True, False)
job_df2['d2_ss_match_yn'] = np.where(job_df2.person_prefer_d2_ss == job_df2.contents_attr_d_ss, True, False)

#d3
job_df2['d3_c_match_yn'] = np.where(job_df2.person_prefer_d3_c == job_df2.contents_attr_d_c, True, False)
job_df2['d3_l_match_yn'] = np.where(job_df2.person_prefer_d3_l == job_df2.contents_attr_d_l, True, False)
job_df2['d3_m_match_yn'] = np.where(job_df2.person_prefer_d3_m == job_df2.contents_attr_d_m, True, False)
job_df2['d3_s_match_yn'] = np.where(job_df2.person_prefer_d3_s == job_df2.contents_attr_d_s, True, False)
job_df2['d3_ss_match_yn'] = np.where(job_df2.person_prefer_d3_ss == job_df2.contents_attr_d_ss, True, False)

#h2
job_df2['h2_c_match_yn'] = np.where(job_df2.person_prefer_h2_c == job_df2.contents_attr_h_c, True, False)
job_df2['h2_l_match_yn'] = np.where(job_df2.person_prefer_h2_l == job_df2.contents_attr_h_l, True, False)
job_df2['h2_m_match_yn'] = np.where(job_df2.person_prefer_h2_m == job_df2.contents_attr_h_m, True, False)

#h3
job_df2['h3_c_match_yn'] = np.where(job_df2.person_prefer_h3_c == job_df2.contents_attr_h_c, True, False)
job_df2['h3_l_match_yn'] = np.where(job_df2.person_prefer_h3_l == job_df2.contents_attr_h_l, True, False)
job_df2['h3_m_match_yn'] = np.where(job_df2.person_prefer_h3_m == job_df2.contents_attr_h_m, True, False)

# %%
# 날짜컬럼생성
job_df2['contents_open_month'] = job_df2['contents_open_dt'].str.slice(5,7)
job_df2['contents_open_day'] = job_df2['contents_open_dt'].str.slice(8,10)
job_df2['contents_open_hour'] = job_df2['contents_open_dt'].str.slice(11,13).str.replace(':','')
job_df2['contents_open_month'] = job_df2['contents_open_dt'].str.slice(5,7)
job_df2['contents_open_day'] = job_df2['contents_open_dt'].str.slice(8,10)
job_df2['contents_open_hour'] = job_df2['contents_open_dt'].str.slice(11,13).str.replace(':','')

# %%
# 속성E 매칭여부
job_df2['e_match_yn'] = np.where(job_df2.person_prefer_e == job_df2.contents_attribute_e, True, False)

# 속성E 코드값 차이
job_df2['e_diff_abs'] = np.abs(job_df2['person_prefer_e']-job_df2['contents_attribute_e'])

# %%
# 속성D 코드 확률 테이블 생성
attr_d_c_diff = job_df2.groupby(['contents_attr_d_c','target'])['target'].count().unstack('target')
attr_d_c_diff = attr_d_c_diff.fillna(0)
attr_d_c_diff['diff'] = attr_d_c_diff[1] - attr_d_c_diff[0]
attr_d_c_diff['sum'] = attr_d_c_diff[1] + attr_d_c_diff[0]
attr_d_c_diff['true_ratio_d_c'] = attr_d_c_diff[1]/attr_d_c_diff['sum']

# D 대분류 확률 테이블 생성
attr_d_l_diff = job_df2.groupby(['contents_attr_d_l','target'])['target'].count().unstack('target')
attr_d_l_diff = attr_d_l_diff.fillna(0)
attr_d_l_diff['diff'] = attr_d_l_diff[1] - attr_d_l_diff[0]
attr_d_l_diff['sum'] = attr_d_l_diff[1] + attr_d_l_diff[0]
attr_d_l_diff['true_ratio_d_l'] = attr_d_l_diff[1]/attr_d_l_diff['sum']

# D 중분류 확률 테이블 생성
attr_d_m_diff = job_df2.groupby(['contents_attr_d_m','target'])['target'].count().unstack('target')
attr_d_m_diff = attr_d_m_diff.fillna(0)
attr_d_m_diff['diff'] = attr_d_m_diff[1] - attr_d_m_diff[0]
attr_d_m_diff['sum'] = attr_d_m_diff[1] + attr_d_m_diff[0]
attr_d_m_diff['true_ratio_d_m'] = attr_d_m_diff[1]/attr_d_m_diff['sum']

# D 소분류 확률 테이블 생성
attr_d_s_diff = job_df2.groupby(['contents_attr_d_s','target'])['target'].count().unstack('target')
attr_d_s_diff = attr_d_s_diff.fillna(0)
attr_d_s_diff['diff'] = attr_d_s_diff[1] - attr_d_s_diff[0]
attr_d_s_diff['sum'] = attr_d_s_diff[1] + attr_d_s_diff[0]
attr_d_s_diff['true_ratio_d_s'] = attr_d_s_diff[1]/attr_d_s_diff['sum']

# D 세분류 확률 테이블 생성
attr_d_ss_diff = job_df2.groupby(['contents_attr_d_ss','target'])['target'].count().unstack('target')
attr_d_ss_diff = attr_d_ss_diff.fillna(0)
attr_d_ss_diff['diff'] = attr_d_ss_diff[1] - attr_d_ss_diff[0]
attr_d_ss_diff['sum'] = attr_d_ss_diff[1] + attr_d_ss_diff[0]
attr_d_ss_diff['true_ratio_d_ss'] = attr_d_ss_diff[1]/attr_d_ss_diff['sum']

# %%
# 속성L 코드 확률 테이블 생성
attr_l_c_diff = job_df2.groupby(['contents_attr_l_c','target'])['target'].count().unstack('target')
attr_l_c_diff = attr_l_c_diff.fillna(0)
attr_l_c_diff['diff'] = attr_l_c_diff[1] - attr_l_c_diff[0]
attr_l_c_diff['sum'] = attr_l_c_diff[1] + attr_l_c_diff[0]
attr_l_c_diff['true_ratio_l_c'] = attr_l_c_diff[1]/attr_l_c_diff['sum']

# L 대분류 확률 테이블 생성
attr_l_l_diff = job_df2.groupby(['contents_attr_l_l','target'])['target'].count().unstack('target')
attr_l_l_diff = attr_l_l_diff.fillna(0)
attr_l_l_diff['diff'] = attr_l_l_diff[1] - attr_l_l_diff[0]
attr_l_l_diff['sum'] = attr_l_l_diff[1] + attr_l_l_diff[0]
attr_l_l_diff['true_ratio_l_l'] = attr_l_l_diff[1]/attr_l_l_diff['sum']

# L 중분류 확률 테이블 생성
attr_l_m_diff = job_df2.groupby(['contents_attr_l_m','target'])['target'].count().unstack('target')
attr_l_m_diff = attr_l_m_diff.fillna(0)
attr_l_m_diff['diff'] = attr_l_m_diff[1] - attr_l_m_diff[0]
attr_l_m_diff['sum'] = attr_l_m_diff[1] + attr_l_m_diff[0]
attr_l_m_diff['true_ratio_l_m'] = attr_l_m_diff[1]/attr_l_m_diff['sum']

# L 소분류 확률 테이블 생성
attr_l_s_diff = job_df2.groupby(['contents_attr_l_s','target'])['target'].count().unstack('target')
attr_l_s_diff = attr_l_s_diff.fillna(0)
attr_l_s_diff['diff'] = attr_l_s_diff[1] - attr_l_s_diff[0]
attr_l_s_diff['sum'] = attr_l_s_diff[1] + attr_l_s_diff[0]
attr_l_s_diff['true_ratio_l_s'] = attr_l_s_diff[1]/attr_l_s_diff['sum']

# L 세분류 확률 테이블 생성
attr_l_ss_diff = job_df2.groupby(['contents_attr_l_ss','target'])['target'].count().unstack('target')
attr_l_ss_diff = attr_l_ss_diff.fillna(0)
attr_l_ss_diff['diff'] = attr_l_ss_diff[1] - attr_l_ss_diff[0]
attr_l_ss_diff['sum'] = attr_l_ss_diff[1] + attr_l_ss_diff[0]
attr_l_ss_diff['true_ratio_l_ss'] = attr_l_ss_diff[1]/attr_l_ss_diff['sum']

# %%
# 속성H 코드 확률 테이블 생성
attr_h_c_diff = job_df2.groupby(['contents_attr_h_c','target'])['target'].count().unstack('target')
attr_h_c_diff = attr_h_c_diff.fillna(0)
attr_h_c_diff['diff'] = attr_h_c_diff[1] - attr_h_c_diff[0]
attr_h_c_diff['sum'] = attr_h_c_diff[1] + attr_h_c_diff[0]
attr_h_c_diff['true_ratio_h_c'] = attr_h_c_diff[1]/attr_h_c_diff['sum']

# H 대분류 확률 테이블 생성
attr_h_l_diff = job_df2.groupby(['contents_attr_h_l','target'])['target'].count().unstack('target')
attr_h_l_diff = attr_h_l_diff.fillna(0)
attr_h_l_diff['diff'] = attr_h_l_diff[1] - attr_h_l_diff[0]
attr_h_l_diff['sum'] = attr_h_l_diff[1] + attr_h_l_diff[0]
attr_h_l_diff['true_ratio_h_l'] = attr_h_l_diff[1]/attr_h_l_diff['sum']

# H 중분류 확률 테이블 생성
attr_h_m_diff = job_df2.groupby(['contents_attr_h_m','target'])['target'].count().unstack('target')
attr_h_m_diff = attr_h_m_diff.fillna(0)
attr_h_m_diff['diff'] = attr_h_m_diff[1] - attr_h_m_diff[0]
attr_h_m_diff['sum'] = attr_h_m_diff[1] + attr_h_m_diff[0]
attr_h_m_diff['true_ratio_h_m'] = attr_h_m_diff[1]/attr_h_m_diff['sum']

# %%
# 콘텐츠 D 속성 확률값으로 대체
job_df2['contents_attr_d_c'] = pd.merge(job_df2, attr_d_c_diff.reset_index(), how='left', on='contents_attr_d_c')['true_ratio_d_c']
job_df2['contents_attr_d_l'] = pd.merge(job_df2, attr_d_l_diff.reset_index(), how='left', on='contents_attr_d_l')['true_ratio_d_l']
job_df2['contents_attr_d_m'] = pd.merge(job_df2, attr_d_m_diff.reset_index(), how='left', on='contents_attr_d_m')['true_ratio_d_m']
job_df2['contents_attr_d_s'] = pd.merge(job_df2, attr_d_s_diff.reset_index(), how='left', on='contents_attr_d_s')['true_ratio_d_s']
job_df2['contents_attr_d_ss'] = pd.merge(job_df2, attr_d_ss_diff.reset_index(), how='left', on='contents_attr_d_ss')['true_ratio_d_ss']

# 콘텐츠 L 속성 확률값으로 대체
job_df2['contents_attr_l_c'] = pd.merge(job_df2, attr_l_c_diff.reset_index(), how='left', on='contents_attr_l_c')['true_ratio_l_c']
job_df2['contents_attr_l_l'] = pd.merge(job_df2, attr_l_l_diff.reset_index(), how='left', on='contents_attr_l_l')['true_ratio_l_l']
job_df2['contents_attr_l_m'] = pd.merge(job_df2, attr_l_m_diff.reset_index(), how='left', on='contents_attr_l_m')['true_ratio_l_m']
job_df2['contents_attr_l_s'] = pd.merge(job_df2, attr_l_s_diff.reset_index(), how='left', on='contents_attr_l_s')['true_ratio_l_s']
job_df2['contents_attr_l_ss'] = pd.merge(job_df2, attr_l_ss_diff.reset_index(), how='left', on='contents_attr_l_ss')['true_ratio_l_ss']

# 콘텐츠 H 속성 확률값으로 대체
job_df2['contents_attr_h_c'] = pd.merge(job_df2, attr_h_c_diff.reset_index(), how='left', on='contents_attr_h_c')['true_ratio_h_c']
job_df2['contents_attr_h_l'] = pd.merge(job_df2, attr_h_l_diff.reset_index(), how='left', on='contents_attr_h_l')['true_ratio_h_l']
job_df2['contents_attr_h_m'] = pd.merge(job_df2, attr_h_m_diff.reset_index(), how='left', on='contents_attr_h_m')['true_ratio_h_m']

# %%
for i in ['d1_c_match_yn','d1_l_match_yn','d1_m_match_yn','d1_s_match_yn','d1_ss_match_yn',
           'd2_c_match_yn','d2_l_match_yn','d2_m_match_yn','d2_s_match_yn','d2_ss_match_yn',
           'd3_c_match_yn','d3_l_match_yn','d3_m_match_yn','d3_s_match_yn','d3_ss_match_yn',
           'h1_c_match_yn','h1_l_match_yn','h1_m_match_yn',
           'h2_c_match_yn','h2_l_match_yn','h2_m_match_yn',
           'h3_c_match_yn','h3_l_match_yn','h3_m_match_yn',
           'e_match_yn'
         ]:
    job_df2[i] = job_df2[i].astype('int')

# %%
job_df2.drop(['id','person_prefer_f','person_prefer_g','contents_open_dt','contents_attribute_d',
              'contents_attribute_h','contents_attribute_l','contents_rn','person_rn',
              'person_prefer_d_1','person_prefer_d_2','person_prefer_d_3',
              'person_prefer_h_1','person_prefer_h_2','person_prefer_h_3',
              'person_prefer_d1_c','person_prefer_d1_l','person_prefer_d1_m','person_prefer_d1_s','person_prefer_d1_ss',
              'person_prefer_d2_c','person_prefer_d2_l','person_prefer_d2_m','person_prefer_d2_s','person_prefer_d2_ss',
              'person_prefer_d3_c','person_prefer_d3_l','person_prefer_d3_m','person_prefer_d3_s','person_prefer_d3_ss',
              'person_prefer_h1_c','person_prefer_h1_l','person_prefer_h1_m',
              'person_prefer_h2_c','person_prefer_h2_l','person_prefer_h2_m',
              'person_prefer_h3_c','person_prefer_h3_l','person_prefer_h3_m'],axis='columns',inplace=True)

# %%
for i in ['contents_open_hour','contents_open_day','contents_open_month']:
    job_df2[i] = job_df2[i].astype('int')

# %%
train_df2 = job_df2.loc[job_df2.target.notnull(),:]
test_df2 = job_df2.loc[job_df2.target.isnull(),:]

# %%
test_df2 = test_df2.drop(['target'], axis='columns')

# %%
from sklearn.model_selection import train_test_split
 
x = train_df2.drop(['target'],axis='columns')
y = train_df2['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (351365, 55)
# (150586, 55)
# (351365,)
# (150586,)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.metrics import f1_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import statsmodels.api as sm
 
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)

x2 = sm.add_constant(x_train)
model = sm.OLS(y_train, x2)
result = model.fit()
print(result.summary())

y_pred = log_reg.predict(x_test)
print('F1 Score :', metrics.f1_score(y_test, y_pred))
# Out:
# C:\Users\82109\anaconda3\envs\pytorch\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     471.5
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):               0.00
# Time:                        18:45:27   Log-Likelihood:            -2.4251e+05
# ...

# %% [markdown]
# ### Dimention Reduction

# %% [markdown]
# #### (1) Stepwise Logistic Regression

# %%
## 단계별 선택법
variables = x.columns.tolist() ## 설명 변수 리스트

selected_variables = [] ## 선택된 변수들
sl_enter = 0.05
sl_remove = 0.05
 
sv_per_step = [] ## 각 스텝별로 선택된 변수들
adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
steps = [] ## 스텝
step = 0
while len(variables) > 0:
    remainder = list(set(variables) - set(selected_variables))
    pval = pd.Series(index=remainder) ## 변수의 p-value
    ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
    ## 모형을 적합한다.
    for col in remainder: 
        x2 = x[selected_variables+[col]]
        x2 = sm.add_constant(x2)
        model = sm.OLS(y,x2).fit()
        pval[col] = model.pvalues[col]
 
    min_pval = pval.min()
    if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
        selected_variables.append(pval.idxmin())
        ## 선택된 변수들에 대해서 어떤 변수를 제거할지 고른다.
        while len(selected_variables) > 0:
            selected_X = x[selected_variables]
            selected_X = sm.add_constant(selected_X)
            selected_pval = sm.OLS(y,selected_X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
            max_pval = selected_pval.max()
            if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                remove_variable = selected_pval.idxmax()
                selected_variables.remove(remove_variable)
            else:
                break
        
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(y,sm.add_constant(x[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break
# Out:
# C:\Users\82109\AppData\Local\Temp/ipykernel_6572/3392323176.py:14: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pval = pd.Series(index=remainder) ## 변수의 p-value
# C:\Users\82109\AppData\Local\Temp/ipykernel_6572/3392323176.py:14: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pval = pd.Series(index=remainder) ## 변수의 p-value
# C:\Users\82109\AppData\Local\Temp/ipykernel_6572/3392323176.py:14: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pval = pd.Series(index=remainder) ## 변수의 p-value
# ...

# %%
selected_variables
# Out:
# ['d1_m_match_yn',
#  'contents_attr_d_s',
#  'contents_attr_l_s',
#  'contents_attr_l_c',
#  'contents_attr_h_c',
#  'contents_attr_d_c',
#  'd2_l_match_yn',
#  'd1_ss_match_yn',
#  'e_match_yn',
#  'd1_l_match_yn',
#  'd2_s_match_yn',
#  'h1_c_match_yn',
#  'contents_attribute_c',
#  'contents_attribute_j',
#  'contents_attribute_a',
#  'person_prefer_e',
#  'person_prefer_c',
#  'contents_attribute_e',
#  'h1_l_match_yn',
#  'd3_c_match_yn',
#  'd1_c_match_yn',
#  'd2_c_match_yn',
#  'd1_s_match_yn',
#  'contents_attr_l_m',
#  'contents_attribute_m',
#  'd3_s_match_yn',
#  'contents_attribute_j_1',
#  'contents_attr_l_l',
#  'contents_attribute_k',
#  'd3_l_match_yn',
#  'contents_attr_d_l',
#  'person_attribute_a',
#  'person_attribute_a_1',
#  'contents_attr_h_l',
#  'h2_c_match_yn',
#  'h3_l_match_yn',
#  'h1_m_match_yn',
#  'contents_attribute_i',
#  'contents_open_hour',
#  'd2_m_match_yn',
#  'contents_attr_h_m',
#  'e_diff_abs',
#  'person_attribute_b',
#  'd2_ss_match_yn']

# %%
len(selected_variables)
# Out:
# 44

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train[selected_variables], y_train)

x2 = sm.add_constant(x_train[selected_variables])
model = sm.OLS(y_train, x2)
result = model.fit()
print(result.summary())

y_pred = log_reg.predict(x_test[selected_variables])
print('F1 Score :', metrics.f1_score(y_test, y_pred))
# Out:
# C:\Users\82109\anaconda3\envs\pytorch\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     589.0
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:01:52   Log-Likelihood:            -2.4251e+05
# ...

# %% [markdown]
# #### (2) Permutation Importance

# %%
import eli5
from eli5.sklearn import PermutationImportance

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train[selected_variables], y_train)

perm = PermutationImportance(log_reg, random_state=3).fit(x_test[selected_variables], y_test)
eli5.show_weights(perm, feature_names = x_test[selected_variables].columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0192
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 contents_attr_d_c
#             </td>
# ...

# %%
job_df3 = job_df2[['contents_attr_d_c','contents_attr_l_c','contents_attribute_j','d1_l_match_yn','contents_attr_h_c',
                   'contents_attr_h_m','contents_attribute_a','d1_c_match_yn','d2_c_match_yn','h1_l_match_yn','contents_attribute_c',
                   'contents_attribute_j_1','person_prefer_e','person_prefer_c','d3_c_match_yn','e_match_yn','contents_attr_l_l',
                   'd2_s_match_yn','d1_s_match_yn','h1_c_match_yn','d1_ss_match_yn','person_attribute_a_1','d3_s_match_yn','contents_attribute_e',
                   'd3_c_match_yn','h3_l_match_yn','person_attribute_b','target']]

# %%
train_df3 = job_df3.loc[job_df3.target.notnull(),:]
test_df3 = job_df3.loc[job_df3.target.isnull(),:]

# %%
test_df3 = test_df3.drop(['target'], axis='columns')

# %%
from sklearn.model_selection import train_test_split
 
x = train_df3.drop(['target'],axis='columns')
y = train_df3['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (351365, 27)
# (150586, 27)
# (351365,)
# (150586,)

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)

x2 = sm.add_constant(x_train)
model = sm.OLS(y_train, x2)
result = model.fit()
print(result.summary())

y_pred = log_reg.predict(x_test)
print('F1 Score :', metrics.f1_score(y_test, y_pred))
# Out:
# C:\Users\82109\anaconda3\envs\pytorch\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     979.1
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):               0.00
# Time:                        19:15:12   Log-Likelihood:            -2.4273e+05
# ...
